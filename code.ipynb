# %%
import geopandas as gpd
import os

LN = gpd.read_file("LN/LN.shp")
LN

urbanized = gpd.read_file("FHWA_Urbanized_Areas_2010/FHWA_Urbanized_Areas_2010.shp")
urbanized
# Out:
#                                    Name  Area_Type     Latitude     Longitude  \
# 0                      Barbourville, KY  Small Urb  +36.8607419  -083.8547626
# 1                        Beaver Dam, KY  Small Urb  +37.3984456  -086.8740011
# 2                             Berea, KY  Small Urb  +37.5835618  -084.2930193
# 3                     Bowling Green, KY  Urbanized  +36.9556909  -086.4391654
# 4                    Campbellsville, KY  Small Urb  +37.3525543  -085.3464954
# 5                        Carrollton, KY  Small Urb  +38.6862281  -085.1430556
# 6          Central City--Greenville, KY  Small Urb  +37.2015507  -087.1708187
# 7                Cincinnati, OH--KY--IN  Urbanized  +39.1855050  -084.4620433
# 8                   Clarksville, TN--KY  Urbanized  +36.5767710  -087.3455817
# 9                         Cynthiana, KY  Small Urb  +38.3851653  -084.2959299
# 10                         Danville, KY  Small Urb  +37.6301644  -084.7733076
# ...

# %%
# Out:
#                RT_UNIQUE  BEGIN_MP  END_MP D_BEGIN_MP D_END_MP   MILES  \
# 0      030-AU-9005  -000    15.883  23.441    015.883  023.441   7.558
# 1      051-AU-9005  -000     0.000  15.883    000.000  015.883  15.883
# 2      051-AU-9005  -211     0.000   0.402    000.000  000.402   0.402
# 3      051-AU-9005  -221     0.000   0.356    000.000  000.356   0.356
# 4      051-AU-9005  -231     0.000   0.379    000.000  000.379   0.379
# ...                  ...       ...     ...        ...      ...     ...
# 14633  098-XX-2059  -000     0.000   0.198    000.000  000.198   0.198
# 14634  100-XX-1642  -000     0.000   0.080    000.000  000.080   0.080
# 14635  104-XX-0127  -000     0.102   0.286    000.102  000.286   0.184
# 14636  104-XX-0127  -000     0.000   0.102    000.000  000.102   0.102
# 14637  102-XX-0070  -000     0.000   0.054    000.000  000.054   0.054
#
#       GOV_LEVEL              D_GOV_LEVE                        RT_DESCR  \
# ...
